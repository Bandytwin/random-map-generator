# %%
import json

class Node:
    


class Layout:
    
    name = 'My Laptop'
    processor = 'Intel Core'

#create map object


#convert to JSON string
jsonStr = json.dumps(laptop1.__dict__)

#print json string
print(jsonStr)
# Out:
# {"name": "Dell Alienware", "processor": "Intel Core i7"}

# %%
# Out:
# Collecting jupyter_server>=2.0.0
#   Using cached jupyter_server-2.1.0-py3-none-any.whl (365 kB)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (0.13.1)
# Collecting jupyter-events>=0.4.0
#   Using cached jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Using cached jupyter_core-5.1.3-py3-none-any.whl (93 kB)
# Requirement already satisfied: websocket-client in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (3.5.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (5.5.0)
# Requirement already satisfied: packaging in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (21.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (6.4.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (6.2)
# Requirement already satisfied: argon2-cffi in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (21.3.0)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: pyzmq>=24 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (25.0.0)
# Requirement already satisfied: jinja2 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (2.11.3)
# Collecting jupyter-client>=7.4.4
#   Using cached jupyter_client-7.4.9-py3-none-any.whl (133 kB)
# Requirement already satisfied: send2trash in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (1.8.0)
# Requirement already satisfied: pywinpty in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (2.0.2)
# Requirement already satisfied: prometheus-client in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (0.14.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter_server>=2.0.0) (5.8.1)
# Requirement already satisfied: idna>=2.8 in c:\users\acowl\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter_server>=2.0.0) (3.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\acowl\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter_server>=2.0.0) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter_server>=2.0.0) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter_server>=2.0.0) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter_server>=2.0.0) (1.5.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter_server>=2.0.0) (302)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter_server>=2.0.0) (2.5.2)
# Requirement already satisfied: jsonschema[format-nongpl]>=3.2.0 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter_server>=2.0.0) (4.16.0)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: rfc3339-validator in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter_server>=2.0.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter_server>=2.0.0) (0.1.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\acowl\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter_server>=2.0.0) (6.0)
# Requirement already satisfied: bleach in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (4.1.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (2.11.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (1.5.0)
# Requirement already satisfied: testpath in c:\users\acowl\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter_server>=2.0.0) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\acowl\anaconda3\lib\site-packages (from jinja2->jupyter_server>=2.0.0) (2.0.1)
# Requirement already satisfied: fastjsonschema in c:\users\acowl\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter_server>=2.0.0) (2.16.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\acowl\anaconda3\lib\site-packages (from argon2-cffi->jupyter_server>=2.0.0) (21.2.0)
# Collecting pywinpty
#   Using cached pywinpty-2.0.10-cp39-none-win_amd64.whl (1.4 MB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\acowl\anaconda3\lib\site-packages (from packaging->jupyter_server>=2.0.0) (3.0.9)
# Requirement already satisfied: six in c:\users\acowl\anaconda3\lib\site-packages (from websocket-client->jupyter_server>=2.0.0) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\acowl\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter_server>=2.0.0) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\acowl\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter_server>=2.0.0) (21.4.0)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: webcolors>=1.11 in c:\users\acowl\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter_server>=2.0.0) (1.12)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: uri-template in c:\users\acowl\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter_server>=2.0.0) (1.2.0)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\acowl\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter_server>=2.0.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acowl\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter_server>=2.0.0) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\acowl\anaconda3\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter_server>=2.0.0) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\acowl\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter_server>=2.0.0) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\acowl\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter_server>=2.0.0) (1.2.2)
# Installing collected packages: pywinpty, python-json-logger, jupyter-core, jsonpointer, fqdn, jupyter-client, jupyter-server-terminals, isoduration, jupyter-events, jupyter_server
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 jsonpointer-2.3 jupyter-client-7.4.9 jupyter-core-5.1.3 jupyter-events-0.6.3 jupyter-server-terminals-0.4.4 jupyter_server-2.1.0 python-json-logger-2.0.4 pywinpty-2.0.10
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts jupyter-migrate.exe, jupyter-troubleshoot.exe and jupyter.exe are installed in 'C:\Users\acowl\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-kernel.exe, jupyter-kernelspec.exe and jupyter-run.exe are installed in 'C:\Users\acowl\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-events.exe is installed in 'C:\Users\acowl\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-server.exe is installed in 'C:\Users\acowl\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbclassic 0.3.5 requires jupyter-server~=1.8, but you have jupyter-server 2.1.0 which is incompatible.
# jupyterlab 3.4.4 requires jupyter-server~=1.16, but you have jupyter-server 2.1.0 which is incompatible.
# jupyterlab-server 2.10.3 requires jupyter-server~=1.4, but you have jupyter-server 2.1.0 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.

# %%
# Example JSON
{
    "type": "random-map-generator-layout",
    "name": "3 Players",
    "description": "A mod random map layout for three players",
    "version": "1.0.1",
    "playerCount": 3,
    "size": 115,
    "layouts": [{
        "name": "1",
        "nodes": [
            {
                "comment" : "Player start region",
                "id": 1,
                "group": 1,
                "player": 1,
                "point": {"x": [0.5, 0.5], "y": [0.9, 0.9]},
                "fill": 0.05,
                "region_identifier": ["player_start"],
                "primary_building": ["AgnosticTown"],
                "isClaimed": true,
                "difficulty" : [15000, 20000],
                "children" :
                [
                    {
                        "id" : 101,
                        "fill" : 0,
                        "parentGrowthBeforeBirth" : 0.50,
                        "group" : 101,
                        "guardChance" : 1,
                        "difficulty" : [4500, 6500],
                        "region_identifier" : ["treasure_medium"],
                        "spawnChance" : 1
                    },
                    {
                        "id" : 102,
                        "fill" : 0,
                        "parentGrowthBeforeBirth" : 0.75,
                        "group" : 102,
                        "guardChance" : 1,
                        "difficulty": [7500, 10000],
                        "region_identifier" : ["treasure_high"],
                        "spawnChance" : 0.75
                    },
                    {
                        "id" : 103,
                        "fill" : 0.025,
                        "parentGrowthBeforeBirth" : 0.25,
                        "group" : 103,
                        "guardChance" : 1,
                        "difficulty" : [9000, 12000],
                        "region_identifier" : ["center"],
                        "spawnChance" : 0.5
                    }
                ]
            },
            {
                "id": 2,
                "player": 2,
                "group": 1,
                "point": {"x": [0.8, 0.8], "y": [0.3, 0.3]},
                "children" :
                [
                    {
                        "id" : 201,
                        "group" : 101
                    },
                    {
                        "id" : 202,
                        "group" : 102
                    },
                    {
                        "id" : 203,
                        "group" : 103
                    }
                ]
            },
            {
                "id": 3,
                "group": 1,
                "player": 3,
                "point": {"x": [0.2, 0.2], "y": [0.3, 0.3]},
                "children" :
                [
                    {
                        "id" : 301,
                        "group" : 101
                    },
                    {
                        "id" : 302,
                        "group" : 102
                    },
                    {
                        "id" : 303,
                        "group" : 103
                    }
                ]
            },
            {
                "comment" : "Player in-between region",
                "id": 4,
                "group": 2,
                "point": {"x": [0.8, 0.8], "y": [0.7, 0.7]},
                "fill" : 0.025,
                "region_identifier": ["player_support"],
                "primary_building": ["ArleonSmallSettlement", "BaryaSmallSettlement", "LothSmallSettlement", "RanaSmallSettlement"],
                "largeCenterArea" : true,
                "difficultyModifier": 1.25,
                "children" :
                [
                    {
                        "id" : 401,
                        "fill" : 0,
                        "parentGrowthBeforeBirth" : 0.5,
                        "group" : 401,
                        "guardChance" : 1,
                        "difficulty" : [5500, 7500],
                        "region_identifier" : ["treasure_medium"],
                        "spawnChance" : 1
                    },
                    {
                        "id" : 402,
                        "fill" : 0.05,
                        "parentGrowthBeforeBirth" : 0.75,
                        "group" : 402,
                        "guardChance" : 1,
                        "difficulty" : [10000, 15000],
                        "region_identifier" : ["center"],
                        "spawnChance" : 0.33
                    }
                ]
            },
            {
                "id": 5,
                "group": 2,
                "point": {"x": [0.5, 0.5], "y": [0.1, 0.1]},
                "children" :
                [
                    {
                        "id" : 501,
                        "group" : 401
                    },
                    {
                        "id" : 502,
                        "group" : 402
                    }
                ]
            },
            {
                "id": 6,
                "group": 2,
                "point": {"x": [0.2, 0.2], "y": [0.7, 0.7]},
                "children" :
                [
                    {
                        "id" : 601,
                        "group" : 401
                    },
                    {
                        "id" : 602,
                        "group" : 402
                    }
                ]
            },
            {
                "comment" : "Center region",
                "id": 7,
                "group" : 7,
                "point": {"x": [0.4, 0.6], "y": [0.4, 0.6]},
                "fill": 0.15,
                "clearRoads" : 0.55,
                "difficultyModifier": 1.5,
                "region_identifier": ["center"],
                "primary_building": ["ArleonLargeSettlement", "BaryaLargeSettlement", "LothLargeSettlement", "RanaSettlementLarge"],
                "largeCenterArea" : true,
                "children" :
                [
                    {
                        "id" : 701,
                        "group": 701,
                        "parentGrowthBeforeBirth" : 0.1,
                        "fill" : 0,
                        "guardChance" : 0.8,
                        "difficulty" : [10000, 15000],
                        "region_identifier" : ["treasure_high"],
                        "spawnChance" : 1.0
                    },
                    {
                        "id" : 702,
                        "group": 702,
                        "parentGrowthBeforeBirth" : 0.5,
                        "fill" : 0,
                        "guardChance" : 0.8,
                        "difficulty" : [7500, 10000],
                        "region_identifier" : ["treasure_medium", "spire"],
                        "spawnChance" : 0.8
                    },
                    {
                        "id" : 703,
                        "fill" : 0.025,
                        "parentGrowthBeforeBirth" : 0.75,
                        "group" : 703,
                        "guardChance" : 1,
                        "difficulty" : [15000, 20000],
                        "region_identifier" : ["center"],
                        "spawnChance" : 0.33
                    }
                ]
            }
        ],
        "connections": [
            {
                "comment": "Connection between players and their in-between regions",
                "group": 1,
                "nodeFrom": 1,
                "nodeTo": 4,
                "guardChance": 1,
                "difficulty" : [4500, 7500],
                "road": true
            },
            {
                "group": 1,
                "nodeFrom": 2,
                "nodeTo": 5
            },
            {
                "group": 1,
                "nodeFrom": 3,
                "nodeTo": 6
            },
            {
                "comment": "Connection in-between and center region",
                "group": 2,
                "nodeFrom": 4,
                "nodeTo": 7,
                "guardChance": 1,
                "difficulty": [10000, 15000],
                "road": true
            },
            {
                "group": 2,
                "nodeFrom": 5,
                "nodeTo": 7
            },
            {
                "group": 2,
                "nodeFrom": 6,
                "nodeTo": 7
            }
        ]
    }]
}
